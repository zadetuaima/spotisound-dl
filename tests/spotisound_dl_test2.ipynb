# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyOAuth
from sclib import SoundcloudAPI, Track, Playlist
import json
import yt_dlp
import os

with open("key.json", "r") as file:
    api_tokens = json.load(file)

client_secret = api_tokens['client_secret']
client_id = api_tokens['client_id']
redirectURI = api_tokens['redirect']
username = api_tokens['username']

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id,
                                               client_secret=client_secret,
                                               redirect_uri=redirectURI,
                                               scope="playlist-read-private"))

with open("soundcloud_key.json", "r") as sound_file:
    sound_api_tokens = json.load(sound_file)

sound_id = sound_api_tokens['client_id']
sound_api = SoundcloudAPI(client_id=sound_id)

download_path = 'C:/Users/Zade/Downloads/Test' #change this to your desired download directory!

playlist_url = input("Enter the playlist URL (Spotify or SoundCloud): ")

ydl_opts = {
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '320',
    }],
    'outtmpl': f'{download_path}/%(title)s.%(ext)s',
    'quiet': True
}

def download_from_youtube(query, download_path):
    """Download audio from YouTube"""
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        try:
            print(f"Downloading {query}...")
            ydl.download([f"ytsearch:{query}"])
        except Exception as e:
            print(f"Error downloading {query}: {e}")

artist_data = []

def download_spotify_playlist(playlist_id):
    """Download tracks from Spotify playlist."""
    results = sp.playlist_tracks(playlist_id)
    tracks = results['items']
    for item in tracks:
        track = item['track']
        track_name = f"{track['artists'][0]['name']} - {track['name']}"
        artist_data.append(track['artists'][0]['name'])
        download_from_youtube(track_name)

def download_soundcloud_playlist(url):
    """Download tracks from SoundCloud playlist."""
    playlist = sound_api.resolve(url)
    for track in playlist.tracks:
        track_name = f"{track.artist} - {track.title}"
        artist_data.append(track.artist)
        download_from_youtube(track_name)

if "spotify.com" in playlist_url:
    playlist_id = playlist_url.split("/")[-1].split("?")[0]
    download_spotify_playlist(playlist_id)
elif "soundcloud.com" in playlist_url:
    download_soundcloud_playlist(playlist_url)
else:
    print("Invalid URL. Please enter a valid Spotify or SoundCloud playlist URL.")


#https://open.spotify.com/playlist/5aI1EDGrQueO2BrlYDxBSy?si=dbdc2123e4fe4802

#https://soundcloud.com/zade-tuaima/sets/bangers-v2
# Out:
# Enter the playlist URL (Spotify or SoundCloud):  https://soundcloud.com/zade-tuaima/sets/happy
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 76
#      74     download_spotify_playlist(playlist_id)
#      75 elif "soundcloud.com" in playlist_url:
# ---> 76     download_soundcloud_playlist(playlist_url)
#      77 else:
#      78     print("Invalid URL. Please enter a valid Spotify or SoundCloud playlist URL.")
#
# Cell In[1], line 70, in download_soundcloud_playlist(url)
#      68 track_name = f"{track.artist} - {track.title}"
#      69 artist_data.append(track.artist)
# ---> 70 download_from_youtube(track_name)
#
# TypeError: download_from_youtube() missing 1 required positional argument: 'download_path'

# %%
print(spot_artist)

# %%
from mutagen.easyid3 import EasyID3
from mutagen.mp3 import MP3
from mutagen.id3 import ID3, APIC, TIT2, TPE1, TALB, error

file_path = "geeses.mp3"
image_path = "95766-1.png"

audio = MP3(file_path, ID3=ID3)

audio.tags.add(TPE1(encoding=3, text="Santigold?"))  #artist
audio.tags.add(TALB(encoding=3, text="fuck knows"))  #album

with open(image_path, "rb") as img:
    audio.tags.add(
        APIC(
            encoding=0,         
            mime="image/png",   
            type=3,             
            desc="Cover",
            data=img.read()
        )
    )

audio.save()

# %%
def download_spotify_playlist(playlist_id):
    """Download tracks from Spotify playlist and add metadata."""
    results = sp.playlist_tracks(playlist_id)
    tracks = results['items']
    for item in tracks:
        track = item['track']
        track_name = f"{track['artists'][0]['name']} - {track['name']}"
        artist = track['artists'][0]['name']
        album = track['album']['name']
        
        # Download track from YouTube
        file_path = download_from_youtube(track_name)
        
        # Add metadata if download was successful
        if file_path:
            add_metadata(file_path, artist, album)

# %%
def download_from_youtube(query, download_path):

    ydl_opts = {
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '320',  # SET SOUND QUALITY!!!!! 320 for high, 128 for normal
    }],
        'outtmpl': os.path.join(download_path, f'{query}'),
        'quiet': True
}
    
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        except Exception as e:


___________________________________________________________________________________

def add_metadata(file_path, artist, album):
    if os.path.exists(file_path):
        audio = MP3(file_path, ID3=EasyID3)
        audio['artist'] = artist
        audio['album'] = album
        audio.save()



def add_metadata_sound(file_path, artist):
    if os.path.exists(file_path):
        audio = MP3(file_path, ID3=EasyID3)
        audio['artist'] = artist
        audio.save()



___________________________________________________________________________________


def download_spotify_playlist(playlist_id):
    results = sp.playlist_tracks(playlist_id)
    tracks = results['items']
    for item in tracks:
        track = item['track']
        track_name = f"{track['artists'][0]['name']} - {track['name']}"
        artist = track['artists'][0]['name']
        album = track['album']['name']
        
        download_from_youtube(track_name, download_path)
 
        file_path = os.path.join(download_path, f"{track_name}.mp3")
        add_metadata(file_path, artist, album)

___________________________________________________________________________________

def download_soundcloud_playlist(url):
    playlist = sound_api.resolve(url)

    for track in playlist.tracks:
        track_name = f"{track.artist} - {track.title}"
        artist = track.user['username']
        
        download_from_youtube(track_name, download_path)
        file_path = os.path.join(download_path, f"{track_name}.mp3")
        add_metadata_sound(file_path, artist)

___________________________________________________________________________________


if "spotify.com" in playlist_url:
    playlist_id = playlist_url.split("/")[-1].split("?")[0]
    download_spotify_playlist(playlist_id)
elif "soundcloud.com" in playlist_url:
    download_soundcloud_playlist(playlist_url)
else:
    print("Invalid URL. Please enter a valid Spotify or SoundCloud playlist URL.")

#https://open.spotify.com/playlist/5aI1EDGrQueO2BrlYDxBSy?si=dbdc2123e4fe4802

#https://soundcloud.com/zade-tuaima/sets/bangers-v2
# Out:
# Enter the playlist URL (Spotify or SoundCloud):  https://open.spotify.com/playlist/5iWL2aMZe1ngJzAlvYTsS9?si=4d7e060f656b433a
# Downloading Jadu Heart - Dead, Again...
# Downloading North Downs - Nightlife Blues...
# Downloading North Downs - Plastic Clouds...
# Downloading Jadu Heart - Jadu Temple...
# Downloading Jadu Heart - Warm Magic...
# Downloading Jadu Heart - Galaxy Surfing...
# Downloading Jadu Heart - The Love...
# Downloading Jadu Heart - Late Night...
# Downloading Jadu Heart - The Cure...
# Downloading Jadu Heart - Zorah Come Home...
# Downloading Jadu Heart - I'm a Kid...
# Downloading LEISURE - All over You...
# Downloading Jadu Heart - Meeting Faro...
# Downloading Tash Sultana - Jungle...
# Downloading Jai Paul - Str8 Outta Mumbai...
# Downloading Ross from Friends - John Cage...
# Downloading Joe Goddard - Taking Over...
# Downloading Elder Island - Hotel Beds...
# Downloading Jadu Heart - Purity...
# Downloading Bonobo - No Reason...
# Downloading Elder Island - Kape Fear...
# Downloading Frankie Stew and Harvey Gunn - Good Will Hunting...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 download_soundcloud_playlist.playlist.tracks
#
# AttributeError: 'function' object has no attribute 'playlist'

# %%
from sclib import SoundcloudAPI, Track, Playlist

api = SoundcloudAPI()  
track = api.resolve('https://soundcloud.com/itsmeneedle/sunday-morning')

assert type(track) is Track

filename = f'./{track.artist} - {track.title}.mp3'

with open(filename, 'wb+') as file:
    track.write_mp3_to(file)

# %%
from sclib import SoundcloudAPI, Track

api = SoundcloudAPI(client_id=sound_id)

track_url = 'https://soundcloud.com/sonsofcharlie/sons-of-charlie-yxng-fxlks?in=zade-tuaima/sets/bangers-v2'

track = api.resolve(track_url)

if isinstance(track, Track):
    # Define the filename for the downloaded track
    filename = f'{track.artist} - {track.title}.mp3'

    with open(filename, 'wb+') as file:
        track.write_mp3_to(file)

# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyOAuth
from sclib import SoundcloudAPI, Track, Playlist
import json
import yt_dlp
import os
from mutagen.mp3 import MP3
from mutagen.easyid3 import EasyID3

#___________________________________________________________________________________

with open("key.json", "r") as file:
    api_tokens = json.load(file)

client_secret = api_tokens['client_secret']
client_id = api_tokens['client_id']
redirectURI = api_tokens['redirect']
username = api_tokens['username']

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id,
                                               client_secret=client_secret,
                                               redirect_uri=redirectURI,
                                               scope="playlist-read-private"))

with open("soundcloud_key.json", "r") as sound_file:
    sound_api_tokens = json.load(sound_file)

sound_id = sound_api_tokens['client_id']
sound_api = SoundcloudAPI(client_id=sound_id)

download_path = r'C:\Users\Zade\Downloads\Test'  # INSERT DOWNLOAD DIRECTORY HERE <-------------------------

playlist_url = input("Enter the playlist URL (Spotify or SoundCloud): ")


#___________________________________________________________________________________

def download_from_youtube(query, download_path):

    ydl_opts = {
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '320',  # SET SOUND QUALITY!!!!! 320 for high, 128 for normal <--------------------
    }],
        'outtmpl': os.path.join(download_path, f'{query}'),
        'quiet': True
}
    
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        try:
            print(f"Downloading {query}...")
            ydl.download([f"ytsearch:{query}"])
        except Exception as e:
            print(f"Error downloading {query}: {e}")


#___________________________________________________________________________________

def add_metadata(file_path, artist, album):
    """metadata for spotify."""
    if os.path.exists(file_path):
        audio = MP3(file_path, ID3=EasyID3)
        audio['artist'] = artist
        audio['album'] = album
        audio.save()

def add_metadata_sound(file_path, artist):
    """metadata for soundcloud."""
    if os.path.exists(file_path):
        audio = MP3(file_path, ID3=EasyID3)
        audio['artist'] = artist
        audio.save()

def download_artwork(artwork_url, track_name):
    """downloads artwork image spotify."""
    if artwork_url:
        response = requests.get(artwork_url)
        if response.status_code == 200:
            artwork_path = os.path.join(download_path, f"{track_name}_artwork.jpg")
            with open(artwork_path, 'wb') as image_file:
                image_file.write(response.content)
#___________________________________________________________________________________

def download_spotify_playlist(playlist_id):
    """Downloads all tracks from a Spotify playlist using YouTube as a source."""
    results = sp.playlist_tracks(playlist_id)
    tracks = results['items']
    for item in tracks:
        track = item['track']
        track_name = f"{track['artists'][0]['name']} - {track['name']}"
        artist = track['artists'][0]['name']
        album = track['album']['name']
        
        download_from_youtube(track_name, download_path)
 
        file_path = os.path.join(download_path, f"{track_name}.mp3")
        add_metadata(file_path, artist, album)

#___________________________________________________________________________________

def download_soundcloud_playlist(url):
    """Downloads all tracks from a SoundCloud playlist using SoundcloudAPI and embeds artwork."""
    playlist = sound_api.resolve(playlist_url)
    
    if isinstance(playlist, Playlist):
        for track in playlist.tracks:
            if isinstance(track, Track):
                track_name = f"{track.artist} - {track.title}.mp3"
                file_path = os.path.join(download_path, track_name)

                with open(file_path, 'wb+') as file:
                    track.write_mp3_to(file)

                if track.artwork_url:
                    response = requests.get(track.artwork_url)
                    if response.status_code == 200:

                        audio = MP3(file_path, ID3=ID3)
                        audio.tags.add(
                            APIC(
                                encoding=0,  # UTF-8
                                mime='image/jpeg',  # or 'image/png'
                                type=3,  # Cover (front)
                                desc='Cover',
                                data=response.content
                            )
                        )
                        audio.save()

                add_metadata_sound(file_path, track.artist)
                print(f"Track downloaded: {track_name}")

#___________________________________________________________________________________

if "spotify.com" in playlist_url:
    playlist_id = playlist_url.split("/")[-1].split("?")[0]
    download_spotify_playlist(playlist_id)
elif "soundcloud.com" in playlist_url:
    download_soundcloud_playlist(playlist_url)
else:
    print("URL not recognised :((")
# Out:
# Enter the playlist URL (Spotify or SoundCloud):  https://soundcloud.com/zade-tuaima/sets/aurora-filth
# <class 'urllib.error.HTTPError'> HTTP Error 404: Not Found
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 142
#     140     download_spotify_playlist(playlist_id)
#     141 elif "soundcloud.com" in playlist_url:
# --> 142     download_soundcloud_playlist(playlist_url)
#     143 else:
#     144     print("URL not recognised :((")
#
# Cell In[4], line 106, in download_soundcloud_playlist(url)
#     104 def download_soundcloud_playlist(url):
#     105     """Downloads all tracks from a SoundCloud playlist using SoundcloudAPI and embeds artwork."""
# --> 106     playlist = sound_api.resolve(playlist_url)
#     108     if isinstance(playlist, Playlist):
#     109         for track in playlist.tracks:
#
# File ~\Documents\creative_code\spotify_soundcloud_dl\venv\Lib\site-packages\sclib\sync.py:84, in SoundcloudAPI.resolve(self, url)
#      78 url = SoundcloudAPI.RESOLVE_URL.format(
#      79     url=url,
#      80     client_id=self.client_id
#      81 )
#      83 obj = get_obj_from(url)
# ---> 84 if obj['kind'] == 'track':
#      85     return Track(obj=obj, client=self)
#      86 if obj['kind'] in ('playlist', 'system-playlist'):
#
# TypeError: 'bool' object is not subscriptable

# %%
def download_from_youtube(query, download_path):

    ytdl_thumb = {
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '320',  # SET SOUND QUALITY!!!!! 320 for high, 128 for normal <--------------------
    }],
        'outtmpl': os.path.join(download_path, f'{query}'),
        'quiet': True
}
    
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        try:
            print(f"Downloading {query}...")
            ydl.download([f"ytsearch:{query}"])
        except Exception as e:
            print(f"Error downloading {query}: {e}")

# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyOAuth
from sclib import SoundcloudAPI, Track, Playlist
import json
import yt_dlp
import os
from mutagen.mp3 import MP3
from mutagen.easyid3 import EasyID3
import re
import requests
from mutagen.id3 import ID3, APIC

#___________________________________________________________________________________

def sanitize_filename(filename):
    return re.sub(r'[<>:"/\\|?*]', '_', filename)

#___________________________________________________________________________________

with open("key.json", "r") as file:
    api_tokens = json.load(file)

client_secret = api_tokens['client_secret']
client_id = api_tokens['client_id']
redirectURI = api_tokens['redirect']
username = api_tokens['username']

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id,
                                               client_secret=client_secret,
                                               redirect_uri=redirectURI,
                                               scope="playlist-read-private"))

with open("soundcloud_key.json", "r") as sound_file:
    sound_api_tokens = json.load(sound_file)

sound_id = sound_api_tokens['client_id']
sound_api = SoundcloudAPI(client_id=sound_id)

download_path = r'C:\Users\Zade\Downloads\Test'  # <------------------------- INSERT DOWNLOAD DIRECTORY HERE 

playlist_url = input("Enter the playlist URL (Spotify or SoundCloud): ")

#___________________________________________________________________________________

def download_from_youtube(query, download_path):
    sanitized_query = sanitize_filename(query)
    mp3_file_path = os.path.join(download_path, f"{sanitized_query}.mp3")
    thumbnail_file_path = os.path.join(download_path, f"{sanitized_query}.jpg")

    ydl_opts = {
        'format': 'bestaudio/best',
        'postprocessors': [
            {
                'key': 'FFmpegExtractAudio',
                'preferredcodec': 'mp3',
                'preferredquality': '320',  # <------------------------- CHANGE SPOTIFY DOWNLOAD QUALITY (320kbps high quality, 128kbps average quality 
            },
            {
                'key': 'EmbedThumbnail',
            },
        ],
        'writethumbnail': True,
        'outtmpl': os.path.join(download_path, f"{sanitized_query}.%(ext)s"),
        'quiet': True
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        try:
            print(f"Downloading {query}...")
            ydl.download([f"ytsearch:{query}"])

            if os.path.exists(thumbnail_file_path):
                embed_thumbnail_in_mp3(mp3_file_path, thumbnail_file_path)
            else:
                print()
        except Exception as e:
            print()



#___________________________________________________________________________________



def add_metadata(file_path, artist, album): #spotify one
    if os.path.exists(file_path):
        audio = MP3(file_path, ID3=EasyID3)
        audio['artist'] = artist
        audio['album'] = album
        audio.save()

def add_metadata_sound(file_path, artist): #soundcloud one
    if os.path.exists(file_path):
        audio = MP3(file_path, ID3=EasyID3)
        audio['artist'] = artist
        audio.save()

def download_artwork(artwork_url, track_name): #soundcloud one
    if artwork_url:
        response = requests.get(artwork_url)
        if response.status_code == 200:
            artwork_path = os.path.join(download_path, f"{sanitize_filename(track_name)}_artwork.jpg")
            with open(artwork_path, 'wb') as image_file:
                image_file.write(response.content)

def embed_thumbnail_in_mp3(mp3_file_path, thumbnail_file_path): #spotify one
    if os.path.exists(mp3_file_path) and os.path.exists(thumbnail_file_path):
        audio = MP3(mp3_file_path, ID3=ID3)
        with open(thumbnail_file_path, 'rb') as img_file:
            audio.tags.add(
                APIC(
                    encoding=0,  # UTF-8
                    mime='image/jpeg',  # Ensure JPEG format for compatibility
                    type=3,  # Cover (front)
                    desc='Cover',
                    data=img_file.read()
                )
            )
        audio.save()
        print(f"Thumbnail embedded into {mp3_file_path}")
        os.remove(thumbnail_file_path)
    else:
        print(f"Could not find MP3 or thumbnail for embedding: {mp3_file_path}, {thumbnail_file_path}")

#___________________________________________________________________________________

def download_spotify_playlist(playlist_id):
    results = sp.playlist_tracks(playlist_id)
    tracks = results['items']
    for item in tracks:
        track = item['track']
        track_name = sanitize_filename(f"{track['artists'][0]['name']} - {track['name']}")
        artist = track['artists'][0]['name']
        album = track['album']['name']
        
        download_from_youtube(track_name, download_path)
 
        file_path = os.path.join(download_path, f"{track_name}.mp3")
        add_metadata(file_path, artist, album)

#___________________________________________________________________________________

def download_soundcloud_playlist(url):
    playlist = sound_api.resolve(url)
    
    if isinstance(playlist, Playlist):
        for track in playlist.tracks:
            if isinstance(track, Track):
                track_name = sanitize_filename(f"{track.artist} - {track.title}.mp3")
                file_path = os.path.join(download_path, track_name)

                with open(file_path, 'wb+') as file:
                    track.write_mp3_to(file)

                if track.artwork_url:
                    response = requests.get(track.artwork_url)
                    if response.status_code == 200:
                        audio = MP3(file_path, ID3=ID3)
                        audio.tags.add(
                            APIC(
                                encoding=0,  # UTF-8, only use 0,1,2
                                mime='image/jpeg', 
                                type=3,  # Cover (front)
                                desc='Cover',
                                data=response.content
                            )
                        )
                        audio.save()

                add_metadata_sound(file_path, track.artist)
                print(f"Track downloaded: {track_name}")

#___________________________________________________________________________________

if "spotify.com" in playlist_url:
    playlist_id = playlist_url.split("/")[-1].split("?")[0]
    download_spotify_playlist(playlist_id)
elif "soundcloud.com" in playlist_url:
    download_soundcloud_playlist(playlist_url)
else:
    print("URL not recognised :((")
# Out:
# Enter the playlist URL (Spotify or SoundCloud):  https://soundcloud.com/zade-tuaima/sets/bangers-v2
# Track downloaded: elinorac x Butschi - Gedankenstau.mp3
# Track downloaded: MGMT - Kids (DJ Monke style remix).mp3
# Track downloaded: Santigold - Disparate Youth (ΣNDYM Trance Edit) FREE DOWNLOAD.mp3
# Track downloaded: Aj Tracey - Naila (Conducta Edit).mp3
# Track downloaded: Dan Newman - Wiley Ain't Homeless [Free DL].mp3
# Track downloaded: Sons Of Charlie - Yxng Fxlks.mp3
# Track downloaded: STÜM - Gingseng Strip (Lofi Edit) -FREE DL-.mp3
# Track downloaded: SMALL TOWN BOY - BRONSKI BEAT (DESIRE EDIT).mp3
