# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyOAuth
import json
import yt_dlp
import os

key = "key.json"
with open(key, "r") as file:
    api_tokens = json.load(file)

client_secret = api_tokens['client_secret']
client_id = api_tokens['client_id']
redirectURI = api_tokens['redirect']
username = api_tokens['username']

playlist_id = 'https://open.spotify.com/playlist/374IfZMn0uLtxM64bwMnEB?si=c7a4b8bb620844f5' 
download_path = 'C:/Users/Zade/Downloads'  

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id,
                                               client_secret=client_secret,
                                               redirect_uri=redirectURI,
                                               scope="playlist-read-private"))

# %%
def download_from_youtube(query, download_path):
    ydl_opts = {
        'format': 'bestaudio/best',
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '320',
        }],
        'outtmpl': f'{download_path}/%(title)s.%(ext)s',
        'quiet': True
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        try:
            print(f"Downloading {query}...")
            ydl.download([f"ytsearch:{query}"])
        except Exception as e:
            print(f"Error downloading {query}: {e}")

# %%
def get_playlist_tracks(playlist_id):

    results = sp.playlist_tracks(playlist_id)
    tracks = results['items']  
    return tracks

# %%
print(get_playlist_tracks(playlist_id))
# Out:
# [{'added_at': '2022-04-15T01:09:24Z', 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/zadetuaima'}, 'href': 'https://api.spotify.com/v1/users/zadetuaima', 'id': 'zadetuaima', 'type': 'user', 'uri': 'spotify:user:zadetuaima'}, 'is_local': False, 'primary_color': None, 'track': {'preview_url': 'https://p.scdn.co/mp3-preview/7aa2c17834d102b2b60d72d2346718bee78d4d55?cid=d861c4a0cb0440e4af97f853335637c0', 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'explicit': False, 'type': 'track', 'episode': False, 'track': True, 'album': {'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'type': 'album', 'album_type': 'single', 'href': 'https://api.spotify.com/v1/albums/50HtLPABSqUnyE7iVIw8La', 'id': '50HtLPABSqUnyE7iVIw8La', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273534983e126fcad3ac579ee4c', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02534983e126fcad3ac579ee4c', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851534983e126fcad3ac579ee4c', 'width': 64}], 'name': "It'll All Be Over", 'release_date': '2019-05-10', 'release_date_precision': 'day', 'uri': 'spotify:album:50HtLPABSqUnyE7iVIw8La', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FIfw6s4iYUFu6tA3iIIOQ'}, 'href': 'https://api.spotify.com/v1/artists/5FIfw6s4iYUFu6tA3iIIOQ', 'id': '5FIfw6s4iYUFu6tA3iIIOQ', 'name': 'Gerry Read', 'type': 'artist', 'uri': 'spotify:artist:5FIfw6s4iYUFu6tA3iIIOQ'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/50HtLPABSqUnyE7iVIw8La'}, 'total_tracks': 4}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FIfw6s4iYUFu6tA3iIIOQ'}, 'href': 'https://api.spotify.com/v1/artists/5FIfw6s4iYUFu6tA3iIIOQ', 'id': '5FIfw6s4iYUFu6tA3iIIOQ', 'name': 'Gerry Re ...

# %%
tracks = []

for item in get_playlist_tracks(playlist_id):
    track = item['track']
    artist_name = track['artists'][0]['name']
    track_name = track['name']
    search_query = f"{artist_name} - {track_name}"
    tracks.append((search_query, track_name))  # Store query and track name in a tuple

    print(search_query)
# Out:
# Gerry Read - It'll All Be Over - DJ Koze Remix
# Justice - D.A.N.C.E
# Lovebirds - Love's Like Dancin
# Laurence Guy - Your Good Times Will Come
# Dusty Springfield - Spooky - Quinten 909 Extended Remix
# Sophie Lloyd - Calling Out (feat. Dames Brown) - 7" Edit
# Sister Sledge - Lost in Music - Dimitri from Paris Remix [2018 Remaster]
# Justice - Safe and Sound
# O'Flynn - Tru Dancing
# Bosq - Can't Seem to Hide
# Sister Sledge - He's the Greatest Dancer - Dimitri from Paris Remix
# Alan Fitzpatrick - Haven't You Heard - Fitzy's Half Charged Mix
# Dj Streaks - The Best Rapper Alive
# Mtbrd - Do The Thing
# Moomin - Woman To Woman
# Rick Wade - Can't You See
# HNNY - Oma Doris
# Kevin McKay - Gimme Gimme - Club Mix
# Calvin Harris - Acceptable in the 80's
# CHIC - Everybody Dance
# Aaron Childs - Tangerine - Channel Tres Remix
# Bronski Beat - Smalltown Boy
# Sam Paradise - Movin' Straight Ahead
# Joey Negro - Big Blow - Moodena Remix
# Louie Vega - Last Night A DJ Saved My Life (feat. Anané & Tony Touch)
# Qubiko - Disco Connection
# Låpsley - Operator - DJ Koze's Disco Edit
# Steve Monite - Only You - Frankie Francis Disco Jam Edit
# Justice - We Are Your Friends - Justice Vs. Simian
# Mella Dee - Techno Disco Tool
# N Joi - Anthem
# Justice - Phantom Pt II - Soulwax Remix
# Stardust - Music Sounds Better With You
# Duck Sauce - aNYway
# The Souljazz Orchestra - House of Cards
# Juliette Armanet - Le Dernier Jour du Disco
# Hardsoul - Back Together (feat. Ron Carroll) - Classic Mix
# Dominica - Gotta Let You Go - Club Mix

# %%
for query, track_name in tracks:
    download_from_youtube(query, DOWNLOAD_PATH)
# Out:
# Downloading Gerry Read - It'll All Be Over - DJ Koze Remix...
# Downloading Justice - D.A.N.C.E...
# Downloading Lovebirds - Love's Like Dancin...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[99], line 2
#       1 for query, track_name in tracks:
# ----> 2     download_from_youtube(query, DOWNLOAD_PATH)
#
# Cell In[95], line 15, in download_from_youtube(query, download_path)
#      13 try:
#      14     print(f"Downloading {query}...")
# ---> 15     ydl.download([f"ytsearch:{query}"])
#      16 except Exception as e:
#      17     print(f"Error downloading {query}: {e}")
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\YoutubeDL.py:3608, in YoutubeDL.download(self, url_list)
#    3605     raise SameFileError(outtmpl)
#    3607 for url in url_list:
# -> 3608     self.__download_wrapper(self.extract_info)(
#    3609         url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3611 return self._download_retcode
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\YoutubeDL.py:3581, in YoutubeDL.__download_wrapper.<locals>.wrapper(*args, **kwargs)
#    3578 @functools.wraps(func)
#    3579 def wrapper(*args, **kwargs):
#    3580     try:
# -> 3581         res = func(*args, **kwargs)
#    3582     except CookieLoadError:
#    3583         raise
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1614, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1612             raise ExistingVideoReached
#    1613         break
# -> 1614     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1615 else:
#    1616     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1625, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1623 while True:
#    1624     try:
# -> 1625         return func(self, *args, **kwargs)
#    1626     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1627         raise
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1781, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1779 if process:
#    1780     self._wait_for_video(ie_result)
# -> 1781     return self.process_ie_result(ie_result, download, extra_info)
#    1782 else:
#    1783     return ie_result
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1910, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1908 self._sanitize_thumbnails(ie_result)
#    1909 try:
# -> 1910     return self.__process_playlist(ie_result, download)
#    1911 finally:
#    1912     self._playlist_level -= 1
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\YoutubeDL.py:2057, in YoutubeDL.__process_playlist(self, ie_result, download)
#    2051     continue
#    2053 self.to_screen(
#    2054     f'[download] Downloading item {self._format_screen(i + 1, self.Styles.ID)} '
#    2055     f'of {self._format_screen(n_entries, self.Styles.EMPHASIS)}')
# -> 2057 entry_result = self.__process_iterable_entry(entry, download, collections.ChainMap({
#    2058     'playlist_index': playlist_index,
#    2059     'playlist_autonumber': i + 1,
#    2060 }, extra))
#    2061 if not entry_result:
#    2062     failures += 1
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1625, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1623 while True:
#    1624     try:
# -> 1625         return func(self, *args, **kwargs)
#    1626     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1627         raise
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\YoutubeDL.py:2089, in YoutubeDL.__process_iterable_entry(self, entry, download, extra_info)
#    2087 @_handle_extraction_exceptions
#    2088 def __process_iterable_entry(self, entry, download, extra_info):
# -> 2089     return self.process_ie_result(
#    2090         entry, download=download, extra_info=extra_info)
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1860, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1856     return ie_result
#    1857 elif result_type == 'url':
#    1858     # We have to add extra_info to the results because it may be
#    1859     # contained in a playlist
# -> 1860     return self.extract_info(
#    1861         ie_result['url'], download,
#    1862         ie_key=ie_result.get('ie_key'),
#    1863         extra_info=extra_info)
#    1864 elif result_type == 'url_transparent':
#    1865     # Use the information from the embedding page
#    1866     info = self.extract_info(
#    1867         ie_result['url'], ie_key=ie_result.get('ie_key'),
#    1868         extra_info=extra_info, download=False, process=False)
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1614, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1612             raise ExistingVideoReached
#    1613         break
# -> 1614     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1615 else:
#    1616     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1625, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1623 while True:
#    1624     try:
# -> 1625         return func(self, *args, **kwargs)
#    1626     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1627         raise
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\YoutubeDL.py:1760, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1757 self._apply_header_cookies(url)
#    1759 try:
# -> 1760     ie_result = ie.extract(url)
#    1761 except UserNotLive as e:
#    1762     if process:
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\extractor\common.py:741, in InfoExtractor.extract(self, url)
#     738 self.initialize()
#     739 self.to_screen('Extracting URL: %s' % (
#     740     url if self.get_param('verbose') else truncate_string(url, 100, 20)))
# --> 741 ie_result = self._real_extract(url)
#     742 if ie_result is None:
#     743     return None
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\extractor\youtube.py:4568, in YoutubeIE._real_extract(self, url)
#    4565 base_url = self.http_scheme() + '//www.youtube.com/'
#    4566 webpage_url = base_url + 'watch?v=' + video_id
# -> 4568 webpage, master_ytcfg, player_responses, player_url = self._download_player_responses(url, smuggled_data, video_id, webpage_url)
#    4570 playability_statuses = traverse_obj(
#    4571     player_responses, (..., 'playabilityStatus'), expected_type=dict)
#    4573 trailer_video_id = get_first(
#    4574     playability_statuses,
#    4575     ('errorScreen', 'playerLegacyDesktopYpcTrailerRenderer', 'trailerVideoId'),
#    4576     expected_type=str)
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\extractor\youtube.py:4527, in YoutubeIE._download_player_responses(self, url, smuggled_data, video_id, webpage_url)
#    4525     if pp:
#    4526         query['pp'] = pp
# -> 4527     webpage = self._download_webpage(
#    4528         webpage_url, video_id, fatal=False, query=query, headers=self._generate_webpage_headers())
#    4530 master_ytcfg = self.extract_ytcfg(video_id, webpage) or self._get_default_ytcfg()
#    4532 player_responses, player_url = self._extract_player_responses(
#    4533     self._get_requested_clients(url, smuggled_data),
#    4534     video_id, webpage, master_ytcfg, smuggled_data)
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\extractor\common.py:1200, in InfoExtractor._download_webpage(self, url_or_request, video_id, note, errnote, fatal, tries, timeout, *args, **kwargs)
#    1198 while True:
#    1199     try:
# -> 1200         return self.__download_webpage(url_or_request, video_id, note, errnote, None, fatal, *args, **kwargs)
#    1201     except IncompleteRead as e:
#    1202         try_count += 1
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\extractor\common.py:1151, in InfoExtractor.__create_download_methods.<locals>.download_content(self, url_or_request, video_id, note, errnote, transform_source, fatal, encoding, data, headers, query, expected_status, impersonate, require_impersonation)
#    1149     kwargs.pop('transform_source')
#    1150 # The method is fetched by name so subclasses can override _download_..._handle
# -> 1151 res = getattr(self, download_handle.__name__)(url_or_request, video_id, **kwargs)
#    1152 return res if res is False else res[0]
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\extractor\common.py:967, in InfoExtractor._download_webpage_handle(self, url_or_request, video_id, note, errnote, fatal, encoding, data, headers, query, expected_status, impersonate, require_impersonation)
#     965     assert not fatal
#     966     return False
# --> 967 content = self._webpage_read_content(urlh, url_or_request, video_id, note, errnote, fatal,
#     968                                      encoding=encoding, data=data)
#     969 if content is False:
#     970     assert not fatal
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\extractor\common.py:1047, in InfoExtractor._webpage_read_content(self, urlh, url_or_request, video_id, note, errnote, fatal, prefix, encoding, data)
#    1044 def _webpage_read_content(self, urlh, url_or_request, video_id, note=None, errnote=None, fatal=True,
#    1045                           prefix=None, encoding=None, data=None):
#    1046     try:
# -> 1047         webpage_bytes = urlh.read()
#    1048     except TransportError as err:
#    1049         errmsg = f'{video_id}: Error reading response: {err.msg}'
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\yt_dlp\networking\_requests.py:143, in RequestsResponseAdapter.read(self, amt)
#     140 def read(self, amt: int | None = None):
#     141     try:
#     142         # Interact with urllib3 response directly.
# --> 143         return self.fp.read(amt, decode_content=True)
#     145     # See urllib3.response.HTTPResponse.read() for exceptions raised on read
#     146     except urllib3.exceptions.SSLError as e:
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\urllib3\response.py:957, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     954     return data
#     956 if amt is None:
# --> 957     data = self._decode(data, decode_content, flush_decoder)
#     958     if cache_content:
#     959         self._body = data
#
# File ~\Documents\creative_code\spotify_api\venv\Lib\site-packages\urllib3\response.py:481, in BaseHTTPResponse._decode(self, data, decode_content, flush_decoder)
#     479 try:
#     480     if self._decoder:
# --> 481         data = self._decoder.decompress(data)
#     482         self._has_decoded_content = True
#     483 except self.DECODER_ERROR_CLASSES as e:
#
# KeyboardInterrupt:

# %%
sound_key = "soundcloud_key.json"
with open(sound_key, "r") as sound_file:
    sound_api_tokens = json.load(sound_file)

sound_oauth = sound_api_tokens['oauth']
sound_id = sound_api_tokens['client_id']

# %%
from sclib import SoundcloudAPI, Track, Playlist

api = SoundcloudAPI(sound_id)
playlist = api.resolve('https://soundcloud.com/zade-tuaima/sets/whatever')

assert type(playlist) is Playlist

print(playlist.tracks[1])
# Out:
# <sclib.sync.Track object at 0x0000025EF8453490>

# %%
for track in playlist.tracks:
    filename = f'{track.artist} - {track.title}'
    print(filename)
# Out:
# 4AM KRU - Pianos Raining Down [165 to 134 Mix](FREE DOWNLOAD)
# MLZ - TAUSEND STERNE *free download*
# DJ JAMES FROM LEEDS - PUSIO [FREE DL]
# 1011 - next up (scruz edit)
# 666cmg - Sprint on My Nikes
# EDBOY🍑 - Diggles D
# DAVE ERA - Infinite Journeys
# Leonardo - Back It Out
# Skepta - GREAZE MODE (HYU EDIT)
# Luke Shep & Harvey Burgan - Just Can't Get Enough
# Noah Edwards - Flashback (DB x NE)
# ✿ 111loggedin // xxenaa ♡ - ˚₊· ͟͟͞͞➳❥｡ ++_dido_111_mix◃ ۪۪۫۫ ༄ؘ ˑ
# The Prodigy - Everybody In The Place (POLO LILLI Bootleg)
# POLO LILLI - DEEPER LOVE [HE064]
# POLO LILLI - NOSEBLEED 165 [HE064]
# Las Ketchup - Asereje (POLO LILLI Bootleg)

# %%
api = SoundcloudAPI(sound_id)
playlist_url = 'https://soundcloud.com/zade-tuaima/sets/whatever'
playlist = api.resolve(playlist_url)

for track in playlist.tracks:
    track_name = f'{track.artist} - {track.title}'
    print(f"Searching and downloading: {track_name}")

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([f"ytsearch1:{track_name}"])
# Out:
# Searching and downloading: 4AM KRU - Pianos Raining Down [165 to 134 Mix](FREE DOWNLOAD)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 9
#       6 track_name = f'{track.artist} - {track.title}'
#       7 print(f"Searching and downloading: {track_name}")
# ----> 9 with yt_dlp.YoutubeDL(ydl_opts) as ydl:
#      10     ydl.download([f"ytsearch1:{track_name}"])
#
# NameError: name 'ydl_opts' is not defined

# %%
def download_soundcloud_playlist(url):
    playlist = sound_api.resolve(url)
    
    if isinstance(playlist, Playlist):
        for track in playlist.tracks:
            if isinstance(track, Track):
                track_name = (f"{track.artist} - {track.title}.mp3")
                file_path = os.path.join(download_path, track_name)

                with open(file_path, 'wb+') as file:
                    track.write_mp3_to(file)

                    print('Downloading file!')

# %%
with open("soundcloud_key.json", "r") as sound_file:
    sound_api_tokens = json.load(sound_file)

sound_id = sound_api_tokens['client_id']
sound_api = SoundcloudAPI(client_id=sound_id)

download_path = 'C:/Users/Zade/Downloads/Test' #change this to your desired download directory!

# %%
playlist_url = 'https://soundcloud.com/zade-tuaima/sets/happy'

if "soundcloud.com" in playlist_url:
    download_soundcloud_playlist(playlist_url)
# Out:
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!
# Downloading file!

# %%
#Append metadata...

from mutagen.mp3 import MP3
from mutagen.easyid3 import EasyID3
import re
import requests
from mutagen.id3 import ID3, APIC

def add_metadata(file_path, artist, album): 
    if os.path.exists(file_path):
        audio = MP3(file_path, ID3=EasyID3)
        audio['artist'] = artist
        audio['album'] = album
        audio.save()

# %%
def spotify_playlist_meta(playlist_id):
    results = sp.playlist_tracks(playlist_id)
    tracks = results['items']
    for item in tracks:
        track = item['track']
        track_name = sanitize_filename(f"{track['artists'][0]['name']} - {track['name']}")
        artist = track['artists'][0]['name']
        album = track['album']['name']
 
        file_path = os.path.join(download_path, f"{track_name}.mp3")
        add_metadata(file_path, artist, album)
        print('adding metadata!')

# %%
import random


#Hacking spotify to return more than 50 tracks a time!!!!! 
track_ids = []
offsets = [random.randint(0, 1000) for _ in range(2)]  # Generate 3 random offsets
keyword : 'dnb'

for offset in offsets:
    track_results = sp.search(q=f"[keyword]", type="track", limit=50, offset=offset)
    for track in track_results["tracks"]["items"]:
        track_ids.append(track["id"])


print(track_ids)
print(len(track_ids))
# Out:
# ['5aqxkjJYIIySHPXWMwSCU6', '5qLFwyMuLAQGHQ8rmDqYYL', '7IPD68AzLKvpwdL2rMQ9f0', '2m0Mg00KwKpUphsGvOX3BW', '7lk1sgZQHEpml8mtjErqSg', '2rpi40gXAl6UEDhBWWCGmz', '4Ed2D95Z3s4KCMhdvB5AEj', '0Li1RYPHPK6HHwItbE1CL6', '3p4fpZoFn42AHTrsVAi4TX', '3VDaDltOb3Iry5tem5EmTw', '3KMGmHjoGVmQvsHG6b6Fca', '7zoWqpLyB7tACMO23sY5PZ', '2Ofs9CYNPHL0qxXK7jmhAY', '1386MMOinXJYaWuSWblT52', '06v4BtkhfJq1tJC4LyX71N', '6fqNw58oKDg5aWvXwkvGwj', '7GGOYXmIeVLhfB8EPZWwFv', '64AxzQwQGxwQ9ittOvs0qq', '4FQOqBor9ggCbrbg5eVIUf', '06gYV8y0InvTUxnm7kv4ZJ', '4iJlT0M63ZBTgWdKUyGfdR', '4wp9Hr5cNIM4PRdVnOJZFE', '1kCH2nHZgnmA79R0uE1bQN', '6Valx66foSj6QTuBpwSC37', '6BjFVM9BOvpSko8IuxUKfb', '7xPz8gdpE5ZrszpiTAOtzZ', '3079FlSGCTog9YQr0aUVfa', '7ye5FB2itmj25Nnl9cRmPk', '6Ei4eNmqpCgncJkIn3wQLV', '6x4D4l2RpHap77B8JBM1d3', '3n1CNbiSVr7bLuXSVVyZk8', '7nEzGK9gau6sR0yNJBNreb', '0ePHfi7iUgLpPXJkrpJ6Y2', '0QSRLq6QSJPkvW3zY2U8rH', '19Az0ATl7GSVjIcpHLV3LR', '4nPKB95ReCI4beteJCqPBr', '5GVJkPEmk3sYmvr8kdPYTq', '6LN5ckAqTBBWK0q0vjHndq', '2obDOB7t3dDkadZMt8EBi0', '00RBmiGHAnmovM6iX7FoEn', '60TWFoR25OR9iRYUGWNPv0', '707h9RAzPf4ZDRy0zCIgMs', '33rQGVKVEVqt0drETsDiSO', '0syKxNcJeqqOeGuAd3oRoG', '4JXxw6BKmoqWVBLV6yQeE0', '1VsAWhK6Z6Ve9mo9aP0FUe', '09wZDR9WQx04uOjesnAMdi', '0PrQfLYJyduOvK4RIeA6lL', '4wQfkEy0LM6FIwt0ZO39DX', '572ZEaF2fYkErdO7UMpy9s', '02V0eeZ16OGQmJqVP5QIYp', '7dz5PkWSHj7eYBUyb0EwBq', '3aLgGbYnl4Gwrc6BCRd02I', '0F69I8NDgjHS3gmVElE3YG', '21v6w7AJo2FskhtAAGwqoF', '7aIVJQUNl1SHcTIpyfNhjT', '1wDwheoR2W3byGBhivrG5v', '69o97bcPhid8vq0amkOjB7', '2OHtJy2zSyKPJiuxbp5HMW', '1ZZzAqVHK3csFEEMMJXkYL', '23czyaWUO26yQTxWU2cjA0', '6Rx0uMPhuUwBF2zajfT4LI', '7eGgMZzO86uLAZai9nxVKN', '1jWtoHANE3hYNJHuEDUX4m', '4URIc9NUIlhMRCAU2b8B2u', '1UGFPRIip1IyGR2rdlEOOL', '4F9U7ei6r9T0zMvjozhW71', '39ifFDvwDcJltExOgOkIyS', '7mnbDHt88Bae8TVcRYrJoH', '7uYbqQjCnBTmPbnwH3Dl6B', '2aSUZZ2IDsy97I7AkuU5Vp', '1CjiirYkYKGC5QUDY0QH6i', '7ieAMTQqpzmSbVr1zNAgNV', '1YTFulNrKvjdnSeE7ggLxP', '5lPuj5BY3OavsKMqv1cEI8', '1XueFULFkcoM2YDmYKU79H', '19W9HDYnqYZcuaKx4MjaKV', '0ceU0pPKf1XlGsC81z8HNC', '24aGHIOkdZL8McsDnnGwqC', '4kpP7L7cweHLa5NxxiFd6q', '3LgA3u52neZCwsnyloSpvQ', '609o9yXsQPK8kegGDsluzm', '4isi5qrHhKaduDhhXKbqUI', '1FebjwF9l75BU9RseOm0W4', '5YDWuGouOVjclEznzoD9L6', '5reVhh0px3dsOBkMPYLFFk', '0z5W4kr3t2aS1Mrm8rsqYf', '6NjTORT3lYaxKsnNGo4A5p', '55tFf8dIneJHTKmMEg0Zyc', '6DybKUTBXe2gR74DhWPQ2m', '1MzbZutvC4e0EJef2fWbr4', '7uzWF5TPxRP1yzZCna3wVB', '3AtE1HLWXEWwXAYQbgtcK8', '1Q1dUmPnAI4zPwJpCvfFC8', '1KXDgdISSig8T59xseIC5h', '21859XcDeRqPqOYI8jRry2', '1Y4jdQBMps1k7ysiZRtnqa', '7z9BNWeIB2ovA6WYzDy7We', '6ffXq1V6sPc9PgkOUL57gL', '4HkUuDobiLbLaTF2ieragh']
# 100

# %%
track_names = []

for track in track_results["tracks"]["items"]:
    track_names.append(track["name"])

for track in track_names:
    print(track)
# Out:
# How Does It Feel
# WHO NEEDS YOU BABY
# Whatever
# Get Back
# NOTHING
# Thousand Mile Wish
# Bring Em Out
# Hyperdrive
# Dirty Luv
# Jellyfish
# Ms. Receive
# Soul Free
# If You Say So
# Teatime
# 回复术士
# Newborn
# Romantic Music
# Don't Get Me Wrong
# Climate Change
# Sanctuary
# Never Sunny
# All This Hurt
# Consider the Eagle, Pt. I
# Traumerei
# Keyboards Like Never Before Asmr
# Rude English Keyboard Cleaner Pt.5
# You Are Mine
# KEYBLADE
# Key (From “Minecraft”) - Instrumental
# Keyboard Typing, Pt. 112
# Keyboard Typing, Pt. 114
# iPad Keyboard ASMR
# Keyboard Typing, Pt. 111
# Professional Dirty Keyboard Deep Clean Pt.6
# Keyboard Typing, Pt. 116
# Keyboard Typing, Pt. 113
# Key (From “Minecraft”) - Instrumental
# Keyboard Typing, Pt. 121
# Another Mechanical Keyboard
# Keyboard Typing, Pt. 123
# Keyboard Typing, Pt. 120
# Live Righteous
# Keyboard Typing, Pt. 109
# Keyboard Typing, Pt. 115
# Keyboard Tapping
# Kiss
# Falling in and out - Key Ab Ver.
# Stars Go By (Keyframes Main Menu)
# Office Laptop Keyboard Typing - Medium 70 WPM Extended Version
# key2! - sped up
